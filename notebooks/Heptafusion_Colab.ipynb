# %% [markdown]
# # Heptafusion 🧠 - Google Colab Edition
#
# Welcome to the Heptafusion notebook. This tool allows you to merge multiple LLMs directly in Colab.

# %%
# @title Install Dependencies
# Please ensure you have cloned the repository or uploaded the files to Colab
# !pip install torch transformers pyyaml tqdm huggingface_hub numpy

# %%
# @title Run Merge
# !python scripts/run_merge.py --config configs/sample_config.yaml
